# %% [markdown]
# TFIM
# 1. SA と 分割時間 hxの依存性 tfim_sa_tcut_hx_n6
# 2. 1の拡大図

# %%
import qutip as qt
import numpy as np
from pathlib import Path
from datetime import datetime
import matplotlib as mpl
from matplotlib.ticker import MultipleLocator
import matplotlib.patheffects as pe
import matplotlib.pyplot as plt
from matplotlib.gridspec import GridSpec
from functools import lru_cache
import requests
# 通知設定
DISCORD_WEBHOOK_URL = "https://discord.com/api/webhooks/1439055708988375082/6iiXA8J_3Bn1RPWZ8XmPfmfSJp_PkGdaIzt495Ao2fbu_a09VnMJpxmrnSyfN4Wtyc7T"
def notify_discord(message: str):
    payload = {"content": message}
    try:
        r = requests.post(DISCORD_WEBHOOK_URL, json=payload, timeout=5)
        r.raise_for_status()
        print("✅ Discord 通知送信 OK")
    except Exception as e:
        print("⚠ Discord 通知に失敗:", e)

# グラフ設定
mpl.rcParams.update(mpl.rcParamsDefault)
plt.style.use('default')
mpl.rcParams.update({
    "axes.labelsize": 18,   # 軸ラベル
    "xtick.labelsize": 16,  # 目盛り数字
    "ytick.labelsize": 16,
    "lines.linewidth": 2.2, # 線の太さ
    "axes.titlesize": 16,
})

def inward_ticks(ax, major_len=7, minor_len=4, width=1.2):
    ax.minorticks_on()
    ax.tick_params(which='both', direction='in', top=True, right=True, length=major_len, width=width)
    ax.tick_params(which='minor', length=minor_len, width=width)

markers = ['o', 's', '^', 'v', 'D', '*', '+', 'x']
colors = [
    "black",
    "tab:blue",
    "tab:orange",
    "tab:green",
    "tab:purple",
    "tab:red",
    "tab:brown",
    "tab:gray",
]

# hx スイープ用: 小さい hx → 薄い / 大きい hx → 濃い紫
colors_hx = [
    "thistle",
    "plum",
    "orchid",
    "mediumorchid",
    "mediumpurple",
    "purple",
    "indigo",
]

# N スイープ用: N が大きいほど「暖色・濃い」方向
colors_N = [
    "tab:blue",   # 最小 N
    "tab:cyan",
    "tab:green",
    "tab:olive",
    "tab:orange",
    "tab:red",    # 最大 N
    "tab:brown",
    "tab:gray",   # おまけ枠（補助曲線にも使える）
]
OUTDIR = Path("charts")
def save_fig(fig, stem: str):
    fig.savefig(OUTDIR / f"{stem}.pdf", bbox_inches="tight", dpi=300) 
    print(f"saved: {OUTDIR / (stem + '.pdf')}")

# データ保存
DATADIR = Path("data")

# データ読み込み例
# fname = DATADIR / "square_sa_tcut.npz" 

# dat = np.load(fname)

# N_list  = dat["N"]   # shape (nN,)
# hx_list = dat["hx_list"]  # shape (nHx,)
# Tcut_list = dat["Tcut"]
# EE      = dat["EE"]       # shape (nN, nHx)

# %%
# ========= キャッシュ付きヘルパ =========
@lru_cache(maxsize=None)
def get_ops(N):
    """Nだけで決まる演算子たち"""
    cut_pos = N // 2 - 1
    sx, sz = [0.5 * M for M in (qt.sigmax(), qt.sigmaz())]
    I2 = qt.qeye(2)

    def op_at(i, op):
        return qt.tensor([op if k == i else I2 for k in range(N)])

    Sx = [op_at(i, sx) for i in range(N)]
    Sz = [op_at(i, sz) for i in range(N)]

    def H_exchange(i):
        return Sz[i] * Sz[i+1]

    Hcut_unit   = H_exchange(cut_pos)
    Hex_rest_unit = sum(H_exchange(i) for i in range(N-1) if i != cut_pos)
    Hhx_unit    = sum(Sx[i] for i in range(N))

    left_sites = list(range(N//2))
    return Hcut_unit, Hex_rest_unit, Hhx_unit, left_sites


@lru_cache(maxsize=None)
def get_psi0(N, J, hx):
    """(N, J, hx)で決まる初期基底状態"""
    Hcut_unit, Hex_rest_unit, Hhx_unit, _ = get_ops(N)
    H_full = -J * (Hcut_unit + Hex_rest_unit) - hx * Hhx_unit
    _, psi0 = H_full.groundstate(sparse=True)
    return psi0

# シミュレーション関数
# ========= メイン: Tcut ごとの時間発展 =========

def simulate(N, J, hx, Tcut):
    """J, hx, Tcutだけで決まるもの"""
    Hcut_unit, Hex_rest_unit, Hhx_unit, left_sites = get_ops(N)
    psi0 = get_psi0(N, J, hx)

    H_static = -J * Hex_rest_unit - hx * Hhx_unit

    def ramp(t, T_cut):
        if T_cut == 0.0:
            # 瞬時切断：t<=0で1, t>0で0（t=0 から見れば状態は変わらない）
            return 1.0 if t <= 0.0 else 0.0
        if t <= 0.0:
            return 1.0
        if t >= T_cut:
            return 0.0
        return 1.0 - t / T_cut

    Ht = [H_static, [-J * Hcut_unit, lambda t, args: ramp(t, Tcut)]]

    if hx == 0.0:
        rhoL = qt.ptrace(psi0, left_sites)
        return float(qt.entropy_vn(rhoL, base=2))

    if Tcut > 0.0:
        tlist = [0.0, float(Tcut)]
    else:
        tlist = [0.0]

    opts = {
        "method": "bdf",
        "nsteps": 100_000_000,
        "rtol": 1e-6,
        "atol": 1e-8,
        "max_step": (Tcut / 500.0) if Tcut > 0.0 else 0.1,
        "store_states": True,
        "progress_bar": None,
    }

    res = qt.sesolve(Ht, psi0, tlist, e_ops=[], options=opts)
    psi_T = res.states[-1]

    rhoL = qt.ptrace(psi_T, left_sites)
    return float(qt.entropy_vn(rhoL, base=2))

# %%
# 1 基底状態のSA と 横磁場 hx
N_list = [6]
J = 1.0
hx_list = [0.0, 0.067, 0.1, 0.2, 0.5, 1.0]
Tcut_list =  np.linspace(0.0, 10000.0, 101)

# データ読み込み
fname = DATADIR / f"tfim_sa_tcut_hx_n{N}.npz"
dat = np.load(fname, allow_pickle=True)
hx_list = dat["hx_list"]
Tcut_list = dat["Tcut_list"]
SA_all = dat["SA_all"]

for i, N in enumerate(N_list):
    fig, ax = plt.subplots(figsize=(6.9, 4.6))
    # SA_all = []
    for j, hx in enumerate(hx_list):
        print(hx)
        inward_ticks(ax)
        # SA_list = [simulate(N=N, J=J, hx=hx, Tcut=Tcut) for Tcut in Tcut_list]
        ax.plot(
            Tcut_list,
            # SA_list,
            SA_all[j],
            marker=markers[j],
            color=colors_hx[j] if hx != 0.0 else colors[0],
            markersize=8.0,
            markevery=5,
            linewidth=2.5
        )
        # SA_all.append(SA_list)
    
    ax.set_xlim(0.0, 10000.0)
    ax.set_xlabel(r"$T_\mathrm{cut}$", fontsize=24)
    ax.set_ylim(0.0, 1.1)
    ax.set_ylabel(r"$S_A (t = T_\mathrm{cut})$", fontsize=24)
    
    plt.show()

    # # データ保存
    # npz_path = DATADIR / f"tfim_sa_tcut_hx_n{N}.npz"
    # np.savez(
    #     npz_path,
    #     N = N,
    #     hx_list = hx_list,
    #     Tcut_list=Tcut_list,
    #     SA_all=SA_all,
    # )
    
    notify_discord(message=f"tifm sim 6-1 done")
    # グラフ保存
    save_fig(fig=fig, stem=f"tfim_sa_tcut_hx_n{N}")
# Out:
# 0.0
# 0.067
# 0.1
# 0.2
# 0.5
# 1.0
# ✅ Discord 通知送信 OK
# saved: charts/tfim_sa_tcut_hx_n6.pdf

# %%
# 2 基底状態のSA と 横磁場 hx 拡大
N_list = [6]
J = 1.0
hx_list = [0.0, 0.067, 0.1, 0.2, 0.5]
Tcut_list =  np.linspace(0.0, 10.0, 101)

# # データ読み込み
# fname = DATADIR / f"tfim_sa_tcut_hx_n{N}_detailed.npz"
# dat = np.load(fname, allow_pickle=True)
# hx_list = dat["hx_list"]
# Tcut_list = dat["Tcut_list"]
# SA_all = dat["SA_all"]

for i, N in enumerate(N_list):
    fig, ax = plt.subplots(figsize=(6.9, 4.6))
    SA_all = []
    for j, hx in enumerate(hx_list):
        print(hx)
        inward_ticks(ax)
        SA_list = [simulate(N=N, J=J, hx=hx, Tcut=Tcut) for Tcut in Tcut_list]
        ax.plot(
            Tcut_list,
            SA_list,
            # SA_all[j],
            marker=markers[j],
            color=colors_hx[j],
            markersize=6.0,
            markevery=5,
            linewidth=2.2
        )
        SA_all.append(SA_list)
        print(f"hx is {hx}, SA peak = {SA_list[0]}")
    
    ax.set_xlim(0.0, 10.0)
    ax.set_xlabel(r"$T_\mathrm{cut}$", fontsize=24)
    ax.set_ylim(0.975, 1.01)
    ax.set_ylabel(r"$S_A (t = T_\mathrm{cut})$", fontsize=24)

    ax.xaxis.set_major_locator(MultipleLocator(1.0))
    # ax.xaxis.set_minor_locator(MultipleLocator())
    ax.yaxis.set_major_locator(MultipleLocator(0.01))
    # ax.yaxis.set_minor_locator(MultipleLocator())
    
    plt.show()

    # # データ保存
    # npz_path = DATADIR / f"tfim_sa_tcut_hx_n{N}_detailed.npz"
    # np.savez(
    #     npz_path,
    #     N = N,
    #     hx_list = hx_list,
    #     Tcut_list=Tcut_list,
    #     SA_all=SA_all,
    # )
    
    notify_discord(message=f"tifm sim 6-2 done")
    # グラフ保存
    save_fig(fig=fig, stem=f"tfim_sa_tcut_hx_n{N}_detailed")
# Out:
# 0.0
# hx is 0.0, SA peak = 0.5570886936156066
# 0.067
# hx is 0.067, SA peak = 1.000010254129689
# 0.1
# hx is 0.1, SA peak = 0.9999373255911281
# 0.2
# hx is 0.2, SA peak = 0.9903349549358069
# 0.5
# hx is 0.5, SA peak = 0.47318664250573333
# ✅ Discord 通知送信 OK
# saved: charts/tfim_sa_tcut_hx_n6_detailed.pdf
